# %% [markdown]
# ## <center> LGMVIP_DS_October_23_Task_Number_3-1<center>

# %% [markdown]
# ## <center> Neural Network That Can Read Hand Writing<center>

# %% [markdown]
# ## <center> By K. Tiyasha Neogi <center>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Train Test Splitting MNIST Data

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
print("The Shape of Training Dataset is: ",X_train.shape)
print('The Shape of Test Dataset is: ',X_test.shape)
# Out:
# The Shape of Training Dataset is:  (60000, 28, 28)
# The Shape of Test Dataset is:  (10000, 28, 28)

# %%
plt.imshow(X_train[0],cmap='gray')
plt.title('Letter or Number '+str(y_train[0]))
# Out:
# Text(0.5, 1.0, 'Letter or Number 5')

# %%
image_size=[]
for i in range(len(X_train)):
    image_size.append(X_train[i].size)

# %%
print('The size of Image is: ',(math.sqrt(X_train[0].size),math.sqrt(X_train[0].size)))
# Out:
# The size of Image is:  (28.0, 28.0)

# %%
image_width=28
image_height=28
batch_size=128
class_num=10
epochs=20
input_shape=(image_width,image_height,1)

# %% [markdown]
# ## Build the Neural Network Model
#
# ```
# # This is formatted as code
# ```

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 8s 10ms/step - loss: 0.3840 - accuracy: 0.8895 - val_loss: 0.1810 - val_accuracy: 0.9498
# Epoch 2/10
# 750/750 [==============================] - 8s 10ms/step - loss: 0.1801 - accuracy: 0.9491 - val_loss: 0.1340 - val_accuracy: 0.9605
# Epoch 3/10
# 750/750 [==============================] - 7s 9ms/step - loss: 0.1349 - accuracy: 0.9596 - val_loss: 0.1156 - val_accuracy: 0.9663
# Epoch 4/10
# 750/750 [==============================] - 7s 9ms/step - loss: 0.1108 - accuracy: 0.9670 - val_loss: 0.1002 - val_accuracy: 0.9707
# Epoch 5/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0911 - accuracy: 0.9728 - val_loss: 0.0918 - val_accuracy: 0.9728
# Epoch 6/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0789 - accuracy: 0.9758 - val_loss: 0.0897 - val_accuracy: 0.9724
# Epoch 7/10
# 750/750 [==============================] - 4s 5ms/step - loss: 0.0724 - accuracy: 0.9777 - val_loss: 0.0862 - val_accuracy: 0.9756
# Epoch 8/10
# 750/750 [==============================] - 4s 6ms/step - loss: 0.0633 - accuracy: 0.9799 - val_loss: 0.0798 - val_accuracy: 0.9757
# Epoch 9/10
# 750/750 [==============================] - 4s 5ms/step - loss: 0.0566 - accuracy: 0.9826 - val_loss: 0.0813 - val_accuracy: 0.9747
# Epoch 10/10
# 750/750 [==============================] - 5s 7ms/step - loss: 0.0526 - accuracy: 0.9831 - val_loss: 0.0812 - val_accuracy: 0.9762

# %% [markdown]
# ## Model Performance on Test Dataset

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy*100:.2f}%")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0742 - accuracy: 0.9770
# Test accuracy: 97.70%

# %% [markdown]
# ## Make Predictions

# %%
predictions = model.predict(X_test[:5])
# Out:
# 1/1 [==============================] - 0s 62ms/step
